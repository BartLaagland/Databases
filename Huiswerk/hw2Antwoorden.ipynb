# %% [markdown]
# 1.
#
# er geldt $D \rightarrow CE \rightarrow AG \Rightarrow D \rightarrow ACEG$. Hierdoor leiden we af dat $R_1$ en $R_2$ afgesplitst zijn op basis van deze FD.
#
# Antwoord: ja

# %% [markdown]
# 2.
#
# $R_1$ heeft als FD $B \rightarrow D$, $B$ is dus een superkey en dus is $R_1$ in BCNF.
#
# $R_2$ heeft als FD's $D \rightarrow ACEG$, wat een superkey is, maar ook $E \rightarrow AG$, wat geen superkey is. We concluderen dat deze niet in BCNF is.
#
# Antwoord: nee

# %% [markdown]
# 3.
#
# $R_1$ is in 3NF aangezien de enige FD $B \rightarrow D$ is. $B$ is een superkey.
#
# $R_2$ heeft de FD's $D \rightarrow ACEG$ en $E \rightarrow AG$. D is een superkey en dus voldoet deze aan de criteria van 3NF. E is geen superkey en $AG$ komt niet voor in een candidate key, deze voldoet dus niet aan de criterie.
#
# Antwoord: nee

# %% [markdown]
# 4.
#
# We hebben in $R_1$, $B \rightarrow D$.
#
# In $R_2$ hebben we, $D \rightarrow CE$, $E \rightarrow AG$
#
# We kunnen hieruit afleiden $B \rightarrow D \rightarrow C \Rightarrow B \rightarrow CD$
#
# Antwoord: ja

# %% [markdown]
# 5.
#
# $(R_3 \cap R_4) = D$ er geldt $D \rightarrow E$, dus D is een super key voor $R_4$
#
# We kunnen nu een join uitvoeren, $R_3 \bowtie R_4 = (BCDE) = R'$
#
# We zien nu
#
# $(R' \cap R_5) = E$ er geldt $E \rightarrow AG$, dus E is een super key voor $R_5$
#
# Antwoord: ja

# %% [markdown]
# 6.
#
# $R_3$ bevat de FD $D \rightarrow C$, $D$ is geen superkey van $R_3$.
#
# Antwoord: nee

# %% [markdown]
# 7.
#
# $R_3$ bevat de FD $D \rightarrow C$, $D$ is geen superkey van $R_3$. Ook merken we op dat C niet in een candidate key zit, de enige candidate key is $B$.
#
# Antwoord: nee

# %% [markdown]
# 8.
#
# We hebben de volgende FD's:
#
# $R_3: B \rightarrow CD, D \rightarrow C$
#
# $R_4: D \rightarrow E$
#
# $R_5: E \rightarrow AG$
#
# Hieruit valt vrij gemakkelijk af te leiden dat dit DP is.

# %% [markdown]
# #### Exercise 2
#
# We gaan uit van het standaard algoritme (normalization, slide 18)
#
# we krijgen dan de FD's:
#
# $$
#     F' = \{BD \rightarrow C, BD \rightarrow E, BD \rightarrow G, D \rightarrow B, D \rightarrow E, E \rightarrow G\}
# $$
#
# (9) We zien dat $D \rightarrow B$, de linkerkant van de $BD$ FD's zijn dus overtollig.
#
# $$
#     F'' = \{D \rightarrow C, D \rightarrow E, D \rightarrow G, D \rightarrow B, D \rightarrow E, E \rightarrow G\}
# $$
#
# (10) We zien dat we nu twee keer $D \rightarrow E$ hebben. Ook zien we dat $D \rightarrow G$ overbodig is.
#
# $$
#     F''' = \{D \rightarrow C, D \rightarrow B, D \rightarrow E, E \rightarrow G\}
# $$

# %% [markdown]
# 11.
# We zien nu dat $F_{\text{min}} = \{D \rightarrow C, D \rightarrow B, D \rightarrow E, E \rightarrow G\}$
#
# We maken voor elke FD uit de minimale cover een relatie:
#
# $R_1 = (DC), R_2 = (DB), R_3 = (DE),R_4 = (EG)$
#
# Merk op dat de candidate keys voor $R$, $AD$ is. $AD$ is niet bevat in deze relaties. We voegen $R_5 = (AD)$ toe.
