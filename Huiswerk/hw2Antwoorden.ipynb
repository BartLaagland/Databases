# %% [markdown]
# 1.
#
# er geldt $D \rightarrow CE \rightarrow AG \Rightarrow D \rightarrow ACEG$. Hierdoor leiden we af dat $R_1$ en $R_2$ afgesplitst zijn op basis van deze FD.
#
# Antwoord: ja

# %% [markdown]
# 2.
#
# $R_1$ heeft als FD $B \rightarrow D$, $B$ is dus een superkey en dus is $R_1$ in BCNF.
#
# $R_2$ heeft als FD's $D \rightarrow ACEG$, wat een superkey is, maar ook $E \rightarrow AG$, wat geen superkey is. We concluderen dat deze niet in BCNF is.
#
# Antwoord: nee

# %% [markdown]
# 3.
#
# $R_1$ is in 3NF aangezien de enige FD $B \rightarrow D$ een superkey is.
#
# $R_2$ heeft de FD's $D \rightarrow ACEG$ en $E \rightarrow AG$. D is een superkey en dus voldoet deze aan de criteria van 3NF. E is geen superkey en $AG$ komt niet voor in een candidate key, deze voldoet dus niet aan de criterie.
#
# Antwoord: nee

# %% [markdown]
# 4.
#
# Nee, alleen $B \rightarrow D$ is af te leiden.
#
# Antwoord: nee

# %% [markdown]
# 5.
#
# De eerste afsplitsing gebeurt over $E \rightarrow AG$
#
# $$
#     R_5 = (AEG)\\
#     R_6 = (BCDE)
# $$
#
# Vervolgens splitsen we $R_6$ af over $D \rightarrow E$
#
# $$
#     R_3 = (BCD)\\
#     R_4 = (DE)\\
#     R_5 = (AEG)
# $$
#
# Antwoord: Ja

# %% [markdown]
# 6.
#
# Elke niet triviale FD bevat een superkey.
#
# Antwoord: Ja

# %% [markdown]
# 7.
#
# Er geldt $\text{BCNF} \Rightarrow \text{3NF}$.
#
# Antwoord: Ja

# %% [markdown]
# 8.
#
# Nee, $D \rightarrow C$ is niet af te leiden.
#
# Antwoord: Nee

# %% [markdown]
# #### Exercise 2
#
# We gaan uit van het standaard algoritme (normalization, slide 18)
#
# we krijgen dan de FD's:
#
# $$
#     F' = \{BD \rightarrow C, BD \rightarrow E, BD \rightarrow G, D \rightarrow B, D \rightarrow E, E \rightarrow G\}
# $$
#
# We zien dat $D \rightarrow B$, de linkerkant van de $BD$ FD's zijn dus overtollig.
#
# $$
#     F'' = \{B \rightarrow C, B \rightarrow E, B \rightarrow G, D \rightarrow B, D \rightarrow E, E \rightarrow G\}
# $$
#
# We zien nu dat $D \rightarrow E$ en $B \rightarrow G$ overtollig zijn.
#
# $$
#     F''' = \{B \rightarrow C, B \rightarrow E, D \rightarrow B,  E \rightarrow G\}
# $$
#
# We concluderen:
#
# $$
# F_{min} = \{B \rightarrow CE, D \rightarrow B,  E \rightarrow G\}
# $$
