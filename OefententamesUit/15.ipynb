# %% [markdown]
# 1 A, fout B
#
# 2 B, fout A
#
# 3 A, klopt
#
# 4 B, klopt
#
# 5 B, klopt
#
# 6 A, fout B
#
# 7 A, klopt
#
# 8 A, klopt
#
# ### 4 punten

# %% [markdown]
# 9 A klopt
#
# 10 A klopt
#
# 11 B klopt
#
# 12 A klopt
#
# 13 B klopt
#
# 14 B klopt
#
# 15 A interpretatie...
#
# 16 A interpretatie...
#
# 17 A klopt
#
# 18 A klopt
#
# 19 A klopt
#
# 20 B klopt
#
# 21 D klopt
#
# ### 22 punten

# %% [markdown]
# 22
#
# We splitsen de rechterkanten op
#
# $$
#     \{ AB \to D, B \to C, BD \to E, C \to E, C \to F, BF \to D \}
# $$
#
# We zien dat $B \to C \to F$, dus $BF \to D$ wordt $B \to D$. We zien ook dat dan $B \to D$  en dus veranderd $BD \to E$ in $B \to E$. Ook zien we dat $AB \to D$ veranderd in $B \to D$
#
# $$
#     \{B \to D, B \to C, B \to E, C \to E, C \to F, B \to D \}
# $$

# %% [markdown]
# 23
#
# We zien dat $B \to E$ overtollig is en dat $B \to D$ twee keer voorkomt

# %% [markdown]
# 24
#
# we hebben
#
# $$
#     \{ B \to C, C \to E, C \to F, B \to D \}
# $$

# %% [markdown]
# 25
# $$
#     R_2(BC), \quad R_3(CE), \quad R_4(CF), \quad R_5(BD)
# $$
#
# ### met wat fout, 12 punten

# %% [markdown]
# 25 B Klopt
#
# 26 A Klopt
#
# 27 B Klopt
#
# 28 A Klopt
#
# 29 A Klopt
#
# 30 B Klopt
#
# ### 12 punten

# %% [markdown]
# 31
#
# E1 en E2 geven alle films waar weleens een vrouw in heeft gespeeld, klopt dus niet. E3 geeft het complement van alle films waar weleens een man in heeft gespeeld, klopt dus wel. E4 klopt volgens mij ook. E8 geeft alle films als er geen films zijn met mannen, klopt dus niet. E9 klopt
#
# Dus E3, E4 en E9
#
# E4 en E9 kloppen niet!
#
#
# 32
#
# E5 slaat nergens op, E10 klopt wel volgens mij
#
# E10 klopt!
#
# 33
#
# E6 klopt niet qua syntax, E7 wel. E11 geeft juist alle namen die niet gelden, complement! E12 klopt ook niet vlm.
#
# dus alleen E7
#
# ook E6 en E11!!
#
# 34
#
# E13 klopt niet, E14 ook niet, E16 ook niet
#
# dus E15
#
# Blijkbaar E16!
#
# ### wss 6 punten

# %% [markdown]
# 35
#
# $$
#     T_2 \to T_1 \\
#     T_2 \to T_3 \\
#     T_2 \to T_5 \\
#     T_3 \to T_5 \\
#     T_4 \to T_2 \\
#     T_4 \to T_3 \\
#     T_4 \to T_5
# $$

# %% [markdown]
# 36
#
# Ja, er is geen cykel, we zien dan op volgord
#
# $T_4, T_2, T_3, T_5, T_1$

# %% [markdown]
# 37
#
# $$
#     T_1 \to T_2 \\
#     T_1 \to T_5 \\
#     T_2 \to T_5 \\
#     T_2 \to T_4 \\
#     T_3 \to T_1 \\
#     T_4 \to T_3 \\
#     T_4 \to T_1
# $$

# %% [markdown]
# 38
#
# Nee we zien $T_1 \to T_2 \to T_4 \to T_1$

# %% [markdown]
# 39 F
#
# Alles goed!
#
# ### 14 punten

# %% [markdown]
# 40
#
# tot en met start T1

# %% [markdown]
# 41
#
# T3, T5, T4

# %% [markdown]
# 42
#
# T2 en T1

# %% [markdown]
# 43
#
# Tot en met start ckpt

# %% [markdown]
# 44
#
# T5

# %% [markdown]
# 55
#
# T2, T3, T4. T3 gedeeltelijk!! dus alleen alles wat na de checkpoint staat, en dat is niks! dus alleen T2 en T4

# %% [markdown]
# ### 9 punten

# %% [markdown]
# 46 B
#
# 47 A
#
# 48 A
#
# 49 A
#
# 50 A
#
# ### 0 punten

# %% [markdown]
# ## 79/100 punten
