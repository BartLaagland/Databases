# %% [markdown]
# 1 B
#
# 2 A
#
# 3 B
#
# 4 B
#
# 5 A
#
# 6 A
#
# 7 A
#
# 8 A

# %% [markdown]
# 9 B
#
# 10 A
#
# 11 B
#
# 12 B
#
# 13 B
#
# 14 A
#
# 15 B
#
# 16 B
#
# 17 B
#
# 18 B
#
# 19 B
#
# 20 B
#
# 21 D

# %% [markdown]
# 22
#
# We hebben
#
# $$
#     F = \{ C \to A, C \to G, A \to D, A\to F, CD \to F, CD \to B, B \to G, F \to G\}
# $$
#
# We zien $C \to A \to D$, volgt
#
# $$
#     F' = \{ C \to A, C \to G, A \to D, A\to F, C \to F, C \to B, B \to G, F \to G\}
# $$

# %% [markdown]
# 23
#
# We zien dat $C \to B \to G$, dus $C \to G$ is overtollig. Ook zien we $C \to A \to F$, dus $C \to F$ is overtollig. volgt
#
# $$
#     F' = \{ C \to A, A \to D, A\to F, C \to B, B \to G, F \to G\}
# $$
#
# Samenvoegen geeft
#
# $$
#     F_{min} = \{ C \to AB, A \to DF, B \to G, F \to G\}
# $$

# %% [markdown]
# 24
#
# $$
#     R_1(CAB), \quad R_2(ADF), \quad R_3(BG), \quad R_4(FG)
# $$

# %% [markdown]
# 25 A
#
# 26 A
#
# 27 B
#
# 28 A
#
# 29 A
#
# 30 A
#
# 31 A
#
# 32 B

# %% [markdown]
# 33
#
# E1, E4, E8 kiest iedereen of niets!, E9 kiest ook complement, E10 komt nieteens in de buurt
#
# dus alleen E1 en E4
#
# Correctie! E1 klopt niet, dit geeft renners die tenminste één editie van AG hebben gereden na 2010!!

# %% [markdown]
# 34
#
# E2 en E3 nemen allebei het jaar niet in rekening
#
# Geen een dus

# %% [markdown]
# 35
#
# E5, E6 geeft het complement, E7 klopt wel
#
# E11 geeft complement, E12 klopt ook niet
#
# dus E5 en E7

# %% [markdown]
# 36
#
# E13 geeft de renners die het hoogst gescoord hebben in 1 wedstrijd
#
# E14 klopt wel

# %% [markdown]
# 37
#
# $$
#     T_2 \to T_5, \\
#     T_1 \to T_3, \\
#     T_2 \to T_5, \\
#     T_2 \to T_1, \\
#     T_2 \to T_4, \\
#     T_5 \to T_1, \\
#     T_5 \to T_4, \\
#     T_1 \to T_3, \\
#     T_1 \to T_4, \\
#     T_3 \to T_5,
# $$
#
# Gesorteerd
#
# $$
#     T_1 \to T_3, \\
#     T_1 \to T_4, \\
#     T_2 \to T_5, \\
#     T_2 \to T_1, \\
#     T_2 \to T_4, \\
#     T_3 \to T_5, \\
#     T_5 \to T_1, \\
#     T_5 \to T_4,
# $$

# %% [markdown]
# 38
#
# Nee, we hebben $T_1 \to T_3 \to T_5 \to T_1$

# %% [markdown]
# 39
#
# $$
#     T_1 \to T_4 \\
#     T_1 \to T_2 \\
#     T_2 \to T_4 \\
#     T_3 \to T_1\\
#     T_4 \to T_2 \\
#     T_5 \to T_3 \\
#     T_5 \to T_1 \\
# $$

# %% [markdown]
# 40
#
# Nee, $T_2 \to T_4 \to T_2$

# %% [markdown]
# 41
#
# Vaag, vraag donderdag!
#
# Waarschijnlijk $F$

# %% [markdown]
# 42
#
# Van commit t2 tot en met start t1

# %% [markdown]
# 43
#
# T2 en T1

# %% [markdown]
# 44
#
# Tot en met start T3, we moeten die namelijk REDO

# %% [markdown]
# 45
#
# Alleen T2, T3 en T4

# %% [markdown]
# 46
#
# Stel het crashed na commit t2, dan zal hij dus de acties van T3 moeten undo, oftewel hij zet $C$ terug naar zijn waarden terwijl T2 denkt dat $C$ nogsteeds 15 is.

# %% [markdown]
# 47 A
#
# 48 A
#
# 49 B
#
# 50 A
#
# 51 B
