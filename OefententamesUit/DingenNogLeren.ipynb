# %% [markdown]
# B-tree met range queries?

# %% [markdown]
# RA goed doornemen!

# %% [markdown]
# Verschil tussen projectie $(\pi)$ en selectie $(\sigma)$ is dus dat projectie alleen kolommen beperkt en selectie bepaalde tupels pakt waarvoor voorwaarden gelden

# %% [markdown]
# Hoe je snel kan zie dat een decompositie verlies vrij is

# %% [markdown]
# SQL queries en division goed leren!

# %% [markdown]
# Kijk de oefentoets van 2016 nog een keer na met recovery!
